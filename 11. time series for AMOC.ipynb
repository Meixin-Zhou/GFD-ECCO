# %%
import numpy as np
import sys
import xarray as xr
import matplotlib.pyplot as plt
from matplotlib.colors import BoundaryNorm
from matplotlib.ticker import MaxNLocator

# %matplotlib inline
import glob
import warnings
warnings.filterwarnings('ignore')
from pprint import pprint
import importlib

import math
import geopy
from geopy import distance

# %%
#download the ECCO grid file

from ecco_download import *

ecco_podaac_download(ShortName="ECCO_L4_GEOMETRY_LLC0090GRID_V4R4",\
                    StartDate="1992-01-01",EndDate="2010-12-31",download_root_dir=None,\
                    n_workers=6,force_redownload=False)
# Out:
# created download directory /home/m267zhou/Downloads/ECCO_V4r4_PODAAC/ECCO_L4_GEOMETRY_LLC0090GRID_V4R4
# {'ShortName': 'ECCO_L4_GEOMETRY_LLC0090GRID_V4R4', 'temporal': '1992-01-01,2010-12-31'}
#
# Total number of matching granules: 1
#
# GRID_GEOMETRY_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# DL Progress: 100%|########################| 1/1 [00:00<00:00, 10645.44it/s]
#
# =====================================
# total downloaded: 0.0 Mb
# avg download speed: 0.0 Mb/s

# %%
# download file (granule) containing 2000 velocities,
# to default path ~/Downloads/ECCO_V4r4_PODAAC/
vol_monthly_shortname = "ECCO_L4_OCEAN_3D_VOLUME_FLUX_LLC0090GRID_MONTHLY_V4R4"
ecco_podaac_download(ShortName=vol_monthly_shortname,\
                    StartDate="1992-01-01",EndDate="2017-12-31",download_root_dir=None,\
                    n_workers=6,force_redownload=False)
# Out:
# created download directory /home/m267zhou/Downloads/ECCO_V4r4_PODAAC/ECCO_L4_OCEAN_3D_VOLUME_FLUX_LLC0090GRID_MONTHLY_V4R4
# {'ShortName': 'ECCO_L4_OCEAN_3D_VOLUME_FLUX_LLC0090GRID_MONTHLY_V4R4', 'temporal': '1992-01-01,2017-12-31'}
#
# Total number of matching granules: 312
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1992-02_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1992-01_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1992-03_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1992-04_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1992-05_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1992-06_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1992-09_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1992-10_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1992-11_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1992-08_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1992-07_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1992-12_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1993-01_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1993-02_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1993-03_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1993-04_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1993-05_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# DL Progress:   0%|                                 | 0/312 [00:00<?, ?it/s]
# OCEAN_3D_VOLUME_FLUX_mon_mean_1993-06_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1993-07_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1993-08_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1993-09_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1993-10_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1993-11_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1994-01_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1994-02_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1993-12_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1994-05_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1994-06_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1994-07_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1994-08_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1994-10_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1994-11_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1994-09_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1995-02_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1995-03_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1995-04_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1995-05_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1995-06_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1995-07_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1994-12_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1995-09_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1995-08_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1995-10_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1996-01_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1994-03_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1996-03_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1996-02_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1996-05_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1995-01_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1996-07_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1996-08_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1996-09_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1995-12_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1996-11_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1996-12_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1997-01_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1996-06_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1997-03_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1995-11_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1997-05_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1997-06_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1997-07_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1997-08_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1997-04_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1997-10_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1996-10_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1997-12_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1998-01_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1998-02_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1998-03_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1998-04_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1998-05_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1998-06_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1998-07_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1998-08_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1998-09_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1998-10_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1998-11_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1998-12_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1999-01_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1999-02_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1999-03_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1999-04_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1999-05_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1999-06_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1999-07_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1999-08_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1999-09_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1999-10_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1999-11_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1999-12_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2000-01_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2000-02_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2000-03_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2000-04_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2000-05_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2000-06_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2000-07_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2000-08_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2000-09_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2000-10_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2000-11_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2000-12_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2001-01_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2001-02_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2001-03_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2001-04_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2001-05_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2001-06_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2001-07_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2001-08_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2001-09_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2001-10_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2001-11_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2001-12_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2002-01_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2002-02_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2002-03_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2002-04_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2002-05_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2002-06_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2002-07_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2002-08_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2002-09_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2002-10_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2002-11_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2002-12_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2003-01_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2003-02_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2003-03_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2003-04_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2003-05_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2003-06_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2003-07_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2003-08_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2003-09_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2003-10_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2003-11_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2003-12_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2004-01_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2004-02_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2004-03_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2004-04_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2004-05_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2004-06_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2004-07_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2004-08_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2004-09_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2004-10_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2004-11_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2004-12_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2005-01_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2005-02_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2005-03_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2005-04_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2005-05_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2005-06_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2005-07_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2005-08_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2005-09_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1997-11_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2005-11_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2005-12_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1996-04_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1994-04_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2006-03_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2006-04_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2006-05_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2006-06_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2006-07_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2006-08_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2006-09_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2006-10_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2006-11_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2006-12_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2007-01_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2007-02_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2007-03_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2007-04_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2007-05_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2007-06_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2007-07_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2007-08_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2007-09_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2007-10_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2007-11_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2007-12_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2008-01_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2008-02_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2008-03_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2008-04_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2008-05_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2008-06_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2008-07_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2008-08_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2008-09_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2008-10_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2008-11_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2008-12_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2009-01_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2009-02_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2009-03_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2009-04_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2009-05_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2009-06_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2009-07_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2009-08_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2009-09_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2009-10_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2009-11_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2009-12_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2010-01_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2010-02_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2010-03_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2010-04_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2010-05_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2010-06_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2010-07_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2010-08_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2010-09_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2010-10_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2010-11_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2010-12_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2011-01_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2011-02_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2011-03_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2011-04_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2011-05_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2011-06_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2011-07_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2011-08_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2011-09_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2011-10_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2011-11_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2011-12_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2012-01_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2012-02_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2012-03_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2012-04_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2012-05_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2012-06_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2012-07_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2012-08_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2012-09_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2012-10_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2012-11_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2012-12_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2013-01_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2013-02_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2013-03_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2013-04_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2013-05_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2013-06_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2013-07_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2013-08_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2013-09_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2013-10_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2013-11_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2013-12_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2014-01_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2014-02_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2014-03_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2014-04_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2014-05_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2014-06_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2014-07_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2014-08_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2014-09_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2014-10_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2014-11_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2014-12_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2015-01_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2015-02_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2015-03_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2015-04_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2015-05_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2015-06_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2015-07_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2015-08_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2015-09_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2015-10_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2015-11_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2015-12_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2016-01_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2016-02_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2016-03_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2016-04_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2016-05_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2016-06_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2016-07_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2016-08_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2016-09_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2016-10_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2016-11_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2016-12_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2017-01_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2017-02_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2017-03_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2017-04_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2017-05_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2017-06_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2017-07_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2017-08_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2017-09_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2017-10_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2017-11_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2017-12_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2006-01_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2005-10_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_2006-02_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1997-02_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
#
# OCEAN_3D_VOLUME_FLUX_mon_mean_1997-09_ECCO_V4r4_native_llc0090.nc already exists, and force=False, not re-downloading
# DL Progress: 100%|####################| 312/312 [00:00<00:00, 27893.48it/s]
#
# =====================================
# total downloaded: 0.0 Mb
# avg download speed: 0.0 Mb/s

# %%
## Import the ecco_v4_py library into Python
## =========================================
##    If ecco_v4_py is not installed in your local Python library, 
##    tell Python where to find it.  The example below adds
##    ecco_v4_py to the user's path if it is stored in the folder
##    ECCOv4-py under the user's home directory

from os.path import join,expanduser
user_home_dir = expanduser('~')

sys.path.append(join(user_home_dir,'ECCOv4-py'))

import ecco_v4_py as ecco

# %%
## Set top-level file directory for the ECCO NetCDF files
## =================================================================

## currently set to ~/Downloads/ECCO_V4r4_PODAAC, 
## the default if ecco_podaac_download was used to download dataset granules
ECCO_dir = join(user_home_dir,'Downloads','ECCO_V4r4_PODAAC')

# %%
## Load the model grid
ecco_grid = xr.open_dataset(glob.glob(join(ECCO_dir,'*GEOMETRY*','*.nc'))[0])

# %%
#To store zonal integral of meridional velovity in 2D arrays (integrate over all longitudes) at latitude of 10 degree over all years 
#in the Atlantic Ocean.
#Dimension is depth by months.
zonal_integral_for_VVELMASS_degree10 = np.zeros((50, 26*12))

# %%
## Load vector fields
ecco_vars1 = xr.open_mfdataset(join(ECCO_dir,'*OCEAN*VOLUME*MONTHLY*','*_1992-*.nc'))
ecco_ds = []

## Merge the ecco_grid with the ecco_vars to make the ecco_ds
ecco_ds = xr.merge((ecco_grid,ecco_vars1)).load()

# %%
# Exclude pacific ocean
xfld = ecco_ds.UVELMASS.isel(k=0, time=0)
yfld = ecco_ds.VVELMASS.isel(k=0, time=0)
# Compute the zonal and meridional vector components of UVEL and VVEL
VEL_E, VEL_N  = ecco.vector_calc.UEVNfromUXVY(xfld, yfld, ecco_ds)
valid_lon_for_each_lat = np.zeros(90)
for lat in range(0,90):
    for lon in range(0,90):
        if (math.isnan(VEL_E.isel(tile=10)[lon,lat]) == True):
            valid_lon_for_each_lat[lat] = lon
            break
        else:
            continue

# %%
#Compute zonal integral for VVELMASS at 10 degree of latitude over all months
for year in range(0, 26):
    y = 1992 + year
    ecco_vars1 = xr.open_mfdataset(join(ECCO_dir,'*OCEAN*VOLUME*MONTHLY*','*_'+str(y)+'-*.nc'))
    ecco_ds = []
    ## Merge the ecco_grid with the ecco_vars to make the ecco_ds
    ecco_ds = xr.merge((ecco_grid,ecco_vars1)).load()
    
    for depth in range(0,50):
        for t in range(0, 12):
            xfld = ecco_ds.UVELMASS.isel(k=depth, time=t)
            yfld = ecco_ds.VVELMASS.isel(k=depth, time=t)
        # Compute the zonal and meridional vector components of UVEL and VVEL
            VEL_E, VEL_N  = ecco.vector_calc.UEVNfromUXVY(xfld, yfld, ecco_ds) 

            sum = 0
            for lon in range(0,89):
                if ((math.isnan(VEL_N.isel(tile=10)[lon,89]) == True) or (valid_lon_for_each_lat[89] >= lon)):
                    sum = sum
                else:
                    sum = sum + VEL_N.isel(tile=10)[lon,89] * distance.distance((VEL_N.isel(tile=10).YC[lon,89], VEL_N.isel(tile=10).XC[lon,89]), (VEL_N.isel(tile=10).YC[lon+1,89], VEL_N.isel(tile=10).XC[lon+1,89])).m
            for lon in range(0,89):
                if (math.isnan(VEL_N.isel(tile=2)[89-89, lon]) == True):
                    sum = sum
                else:
                    sum = sum + VEL_N.isel(tile=2)[89-89, lon] * distance.distance((VEL_N.isel(tile=2).YC[89-89, lon], VEL_N.isel(tile=2).XC[89-89, lon]), (VEL_N.isel(tile=2).YC[89-89, lon+1], VEL_N.isel(tile=2).XC[89-89, lon+1])).m
        
            zonal_integral_for_VVELMASS_degree10[depth, year*12+t] = sum

# %%
#create amoc array
amoc_for_VVELMASS_at_lat10 = np.zeros(26*12)

#get depth array
depth_array = ecco_grid.Z[0:50].values

# %%
#compute amoc at 10 degree of latitude over months
for t in range(0,26*12):
    sum = 0
    arr = np.zeros(49)
    for depth in range(0, 49):
        sum = sum + zonal_integral_for_VVELMASS_degree10[depth, t] *  (-(depth_array[depth+1] - depth_array[depth]))
        arr[depth] = sum
    amoc_for_VVELMASS_at_lat10[t] = np.max(arr)

# %%
#store month array and amoc array in csv file for later use
arr = [np.arange(0, 26*12, 1), amoc_for_VVELMASS_at_lat10/1000000]
np.savetxt("10.csv", arr, delimiter =",")
